# %% [markdown]
# # To-Do-List Suite for analyzing data from an EPR experiment
#
# #### 1) Advertisement and doumentation
#
#   * Creation of an EPR Gihub webpage (https://github.com/TChauvire/EPR_ESR_Suite)
#   * Documentation of the suite program
#
# #### 2) Base functions:
# **The Idea here is to test existing program to optimize the future software.
# In a first option, a GUI software will be avoided as it can time consming to design...**
#
#   * import files python 2D/3D, stacked plot
#   * Class definition: Data, data.smooth, data.fft for 2D/3D type of data and data.param
#   * Fonction plot ??? (Axes, and styles)
#   * Peak detection + FWHM measurement
#   * Function export for preformatting for origin, text ascii type or other format
#   * Function to export figure --> check vectoriel type of export
#   * Function smooth, normalize, denoising --> contact Madhur for this last part
#   * Interface to interact with MATLAB and especially easyspin
#   * Fourier transform Suite (Background subtraction, Windowing, zerofilling, fftshift) and application to 3P-ESEEM
#   * Phase transformation to a first order
#   * Fitting method: Gaussian peak, Lorenzian peak, TM, T1, ... ?
#   * RMSE calculations --> check for some existing statistic tools and library
#   * Export fitting parameters method
#   * Error functions
#   * Test function to evaluate bug in the Suite
#
# **If everything is ready, implementation of some GUI type of software will be achieved.
# --> Check for already implemeted tools...**
#
# #### 3) Existing software or tools in Github
#
#   * [PySpec Suite from John Franck Lab (Syracuse University)](https://jmfrancklab.github.io/)
#     [GitHub Link here](https://github.com/jmfrancklab/pyspecdata)
#     [Documentation here](https://jmfrancklab.github.io/pyspecdata/index.html)
#        1) Pros : seems to be a very elaborated library of function adapted to EPR and ODNP (Overhauser Dynamic Nuclear Polarization NMR) experiments, but also for preformatting scientific report.
#        2) Cons : some scripts seems to be written in Python 2.7 b) the software is still in development.
#   * [madbitloman/lineshape-epr-esr](https://github.com/madbitloman/lineshape-epr-esr)
#   * Morten Albring repository:
#        1) Converter of DSC files in .csv) [mortenalbring/BES3Tconvert](https://github.com/mortenalbring/BES3Tconvert)
#        2) [mortenalbring/EPRSimDiff](https://github.com/mortenalbring/EPRsimDiff)
#
# #### 4) List of required library tools:
#
#   * Interaction with Matlab and Easyspin
#        1) [Full easyspin code on Github](https://github.com/StollLab/EasySpin/)
#        2) [Matlabwrapper tool for windows](https://github.com/Answeror/mlabwrap) and [sourceforge link](http://mlabwrap.sourceforge.net/)
#        3) [matlab-connection](https://pypi.org/project/matlab-connection/)
#        4) [python-matlab-bridge](https://arokem.github.io/python-matlab-bridge/) and [github link](https://github.com/arokem/python-matlab-bridge)
#        5) [pymatlab](https://pypi.python.org/pypi/pymatlab)
#
#   * Interaction with Matlab and DeerAnalysis
#        1) [spintoolbox](https://www.spintoolbox.com/en/offline-tools/deer-plot/)
#        2) [DEERplot](https://github.com/haditim/DEERplot)
#
# #### 5) Extended project with interaction with X-EPR_API tools:
#
#   * [ExEPR](https://github.com/monadnoc/ExEPR)
#   * [Bruker_Xepr_DTA_to_ASCII_Batch_Converter](https://github.com/kippvs/Bruker_Xepr_DTA_to_ASCII_Batch_Converter)
#   * [rpbarnes/ElexsysComp](https://github.com/rpbarnes/ElexsysComp) (written with Python 2.7)
#
# #### 6) Instrumentation hardware tools:
#
#   * [OE-FET/customxepr](https://github.com/OE-FET/customxepr)
